# %% [markdown]
# Project 3 "McNulty" Notebook 1:
# **Prepping and loading data into Postgres**
#
# Adam Flugel
# Metis Boot Camp, Chicago
# Winter 2018

# %%
import pandas as pd
import numpy as np
from collections import defaultdict

# %% [markdown]
# # Import and clean data

# %% [markdown]
# ## Helper Functions

# %%
def drop_nan_columns(data, desired_columns, inplace=True):
    """Drops the columns with the most NaN values from a dataframe.
    Default is inplace. If inplace=false, will return a new dataframe without the dropped columns.
    
    Inputs:
    'data' = pandas dataframe
    'desired_columns' = amount of columns you want to end up with after the drops
    'target' = name of desired target column, will retain regardless of NaN count
    """
    
    col_count = len(data.columns)
    
    assert (col_count > desired_columns),(
        'You only have %s columns. You asked to pare down to %s.'%(col_count, desired_columns))
    
    #creates a list of column names and their NaN totals
    nullcounts = data.isnull().sum()
    droplist = []

    #figure out what proportion of columns we can keep to stick to SQL's 1600 column limit
    proportion_tokeep = desired_columns / col_count
    percent_tokeep = 100 * proportion_tokeep

    #finds the 'cutoff' NaN count - any column above this will be dropped
    cutoff = int( np.percentile(nullcounts, percent_tokeep) )

    #creates a list of columns to drop (NaN count above cutoff)
    for col_name, nullcount in nullcounts.items():
        if nullcount >= cutoff:
            droplist.append(col_name)
    
    if inplace:
        data.drop(droplist, axis=1, inplace=True)
    else:
        return data.drop(droplist, axis=1)

# %% [markdown]
# ## Execution

# %%
df = pd.read_csv('user_data.csv', low_memory=False)
df.rename(columns={'Unnamed: 0':'username'}, inplace=True)  #cleaning first column header

# %%
#Removing any rows without a target value (q220)
df = df.loc[df.q220.notnull()]

#pare down to the 1600 columns with the least NaNs (SQL limitation)
drop_nan_columns(df, 500)

#move the target variable to the rightmost column called 'target'
df['target'] = df.q220
df.drop('q220', axis=1, inplace=True)

# %%
df.to_pickle('raw_1600col_df.gz', compression='gzip')

# %%
df_1600 = pd.read_pickle('raw_1600col_df.gz')

# %%
df_1600
# Out:
#                username          q11  q13  q14  q17  q28  \
# 25       -KorbenDallas-      Aroused   No   No  Yes   No
# 33              -Pucki-    Horrified   No   No   No   No
# 35           -RubyBlue-  Indifferent   No   No   No  Yes
# 39          -shahrizai-      Aroused   No   No   No   No
# 40              -Signe-          NaN   No   No   No   No
# 48           -zeitgeist    Horrified   No   No  Yes   No
# 81       _electric_blue          NaN   No   No  Yes   No
# 95              _jessca          NaN  NaN  Yes   No  NaN
# 120        _Poison-Ivy_          NaN   No   No  NaN  Yes
# 164     10000daystocome    Horrified   No   No  NaN  NaN
# 169        1123581321_S          NaN   No   No   No   No
# 171          11e1even11    Horrified   No  NaN  Yes  NaN
# 176            123mrlee  Indifferent  Yes  NaN  Yes  Yes
# 178           1286Laura      Aroused  NaN  NaN   No   No
# 213                2080          NaN   No   No  Yes   No
# 279          85Wanderer    Horrified   No   No   No  NaN
# 303     a-leafs-whisper  Indifferent   No   No  Yes   No
# 307          a_manda728          NaN  NaN   No  NaN  NaN
# 346              abeyan    Horrified   No   No   No   No
# 365             abscidi    Horrified   No   No   No   No
# 366    abscondingorchid      Aroused   No   No  Yes  Yes
# 438        AdeleDazeeem    Nostalgic   No   No  Yes  Yes
# 443       AdenosinePush  Indifferent   No   No   No   No
# 446          adieterich      Aroused   No   No   No  Yes
# 475       adventurefull          NaN   No   No   No   No
# 527         agooddesign      Aroused   No   No  Yes  Yes
# 549           aimee-loo    Horrified   No   No   No   No
# 553              ainees          NaN   No   No   No  NaN
# 618       alannacrystal          NaN   No   No  NaN   No
# 620           alastair8          NaN   No   No  Yes   No
# ...                 ...          ...  ...  ...  ...  ...
# 68081   u_cant_prove_it          NaN  NaN  NaN  NaN  Yes
# 68083       incidentist          NaN  NaN  NaN  NaN   No
# 68086        _humanoid_          NaN  NaN  NaN  NaN   No
# 68088          miklos54          NaN  NaN  NaN  NaN  NaN
# 68089   aTribeCaldOuest          NaN  NaN  NaN  NaN  NaN
# 68094       jadefires77          NaN  NaN  NaN  NaN  NaN
# 68095         Aquaschaf          NaN  NaN  NaN  NaN  NaN
# 68096     KongDonkey_jr          NaN  NaN  NaN  NaN  NaN
# 68102           Intune1          NaN  NaN  NaN  NaN  NaN
# 68104      aquarius-gal          NaN  NaN  NaN  NaN  NaN
# 68109      woman4awoman          NaN  NaN  NaN  NaN  NaN
# 68122    kitchenwitch75          NaN  NaN  NaN  NaN  NaN
# 68123        Jupiter422          NaN  NaN  NaN  NaN  NaN
# 68126            lwshll          NaN  NaN  NaN  NaN  NaN
# 68131          Roger718          NaN  NaN  NaN  NaN  NaN
# 68132     melanie101882          NaN  NaN  NaN  NaN  NaN
# 68139           DeanMcr          NaN  NaN  NaN  NaN  NaN
# 68150      -lemongrass-          NaN  NaN  NaN  NaN  NaN
# 68161          TipdTop6          NaN  NaN  NaN  NaN  NaN
# 68163      GreenMind206          NaN  NaN  NaN  NaN  NaN
# 68170     atariartaries          NaN  NaN  NaN  NaN  NaN
# 68171         Patty6681          NaN  NaN  NaN  NaN  NaN
# 68180           Dss2014          NaN  NaN  NaN  NaN  NaN
# 68191           okcraig          NaN  NaN  NaN  NaN  NaN
# 68200      CrumpetRebel          NaN  NaN  NaN  NaN  NaN
# 68202            Chazzl          NaN  NaN  NaN  NaN  NaN
# 68213             mosmi          NaN  NaN  NaN  NaN  NaN
# 68215     jackietripher          NaN  NaN  NaN  NaN  NaN
# 68247      neffertiti4u          NaN  NaN  NaN  NaN  NaN
# 68290           elbaite          NaN  NaN  NaN  NaN  NaN
#
#                               q29                 q30  \
# 25                   do the tying           Yes, some
# 33          be tied up during sex                  No
# 35          be tied up during sex                  No
# 39          be tied up during sex           Yes, some
# 40     avoid bondage all together                 NaN
# 48     avoid bondage all together                  No
# 81                            NaN                  No
# 95                            NaN                  No
# 120                  do the tying           Yes, some
# 164         be tied up during sex                 NaN
# 169                  do the tying                 NaN
# 171         be tied up during sex                  No
# 176    avoid bondage all together           Yes, some
# 178         be tied up during sex           Yes, some
# 213                           NaN                 NaN
# 279         be tied up during sex                  No
# 303         be tied up during sex           Yes, some
# 307         be tied up during sex                 NaN
# 346         be tied up during sex           Yes, some
# 365         be tied up during sex           Yes, some
# 366                  do the tying           Yes, some
# 438         be tied up during sex           Yes, some
# 443                  do the tying           Yes, some
# 446         be tied up during sex  Yes, lots and lots
# 475         be tied up during sex                 NaN
# 527                  do the tying           Yes, some
# 549         be tied up during sex           Yes, some
# 553                           NaN                 NaN
# 618                           NaN                 NaN
# 620         be tied up during sex                 NaN
# ...                           ...                 ...
# 68081                         NaN                 NaN
# 68083                         NaN                 NaN
# 68086                         NaN                 NaN
# 68088  avoid bondage all together                  No
# 68089  avoid bondage all together                 NaN
# 68094  avoid bondage all together                 NaN
# 68095  avoid bondage all together                 NaN
# 68096                         NaN                  No
# 68102                         NaN                 NaN
# 68104                         NaN                 NaN
# 68109                         NaN                 NaN
# 68122                         NaN                 NaN
# 68123                         NaN                 NaN
# 68126                         NaN                 NaN
# 68131                         NaN                 NaN
# 68132                         NaN                 NaN
# 68139                         NaN                 NaN
# 68150                         NaN                 NaN
# 68161                         NaN                 NaN
# 68163                         NaN                 NaN
# 68170                         NaN                 NaN
# 68171                         NaN                 NaN
# 68180                         NaN                 NaN
# 68191                         NaN                 NaN
# 68200                         NaN                 NaN
# 68202                         NaN                 NaN
# 68213                         NaN                 NaN
# 68215                         NaN                 NaN
# 68247                         NaN                 NaN
# 68290                         NaN                 NaN
#
#                                  q32   q35  ...    \
# 25                  I have tried it.  Love  ...
# 33     I have little or no interest.  Love  ...
# 35                               NaN  Love  ...
# 39        It seriously interests me.  Love  ...
# 40                               NaN  Love  ...
# 48                  I have tried it.  Love  ...
# 81                               NaN  Love  ...
# 95                               NaN  Love  ...
# 120                 I have tried it.   NaN  ...
# 164                              NaN  Love  ...
# 169    I have little or no interest.   NaN  ...
# 171                 I have tried it.   Sex  ...
# 176       It seriously interests me.   Sex  ...
# 178                 I have tried it.  Love  ...
# 213                              NaN  Love  ...
# 279    I have little or no interest.   Sex  ...
# 303                 I have tried it.  Love  ...
# 307                              NaN  Love  ...
# 346    I have little or no interest.  Love  ...
# 365                              NaN  Love  ...
# 366                 I have tried it.  Love  ...
# 438       It seriously interests me.  Love  ...
# 443       It seriously interests me.  Love  ...
# 446    I have little or no interest.   NaN  ...
# 475                              NaN  Love  ...
# 527                 I have tried it.  Love  ...
# 549       It seriously interests me.   Sex  ...
# 553    I have little or no interest.  Love  ...
# 618    I have little or no interest.  Love  ...
# 620                              NaN   Sex  ...
# ...                              ...   ...  ...
# 68081                            NaN   NaN  ...
# 68083                            NaN   NaN  ...
# 68086                            NaN  Love  ...
# 68088               I have tried it.   NaN  ...
# 68089  I have little or no interest.  Love  ...
# 68094                            NaN  Love  ...
# 68095                            NaN  Love  ...
# 68096                            NaN   NaN  ...
# 68102                            NaN   NaN  ...
# 68104                            NaN  Love  ...
# 68109                            NaN   NaN  ...
# 68122                            NaN  Love  ...
# 68123                            NaN  Love  ...
# 68126                            NaN  Love  ...
# 68131                            NaN  Love  ...
# 68132                            NaN  Love  ...
# 68139                            NaN  Love  ...
# 68150                            NaN  Love  ...
# 68161                            NaN  Love  ...
# 68163                            NaN  Love  ...
# 68170                            NaN  Love  ...
# 68171                            NaN  Love  ...
# 68180                            NaN   NaN  ...
# 68191                            NaN   NaN  ...
# 68200                            NaN   NaN  ...
# 68202                            NaN   NaN  ...
# 68213                            NaN   NaN  ...
# 68215                            NaN   NaN  ...
# 68247                            NaN   NaN  ...
# 68290                            NaN   NaN  ...
#
#                                             q665                    q67418  \
# 25                           Bring out the toys!                       NaN
# 33     Not sure/don't know what they really are.               It's sweet.
# 35                                           NaN  I'm indifferent to this.
# 39                           Bring out the toys!            It's annoying.
# 40                                           NaN            It's annoying.
# 48                                           NaN  I'm indifferent to this.
# 81                                           NaN  I'm indifferent to this.
# 95                                           NaN                       NaN
# 120         Never tried it, but I'm open-minded.                       NaN
# 164                          Bring out the toys!                       NaN
# 169                                          NaN  I'm indifferent to this.
# 171                                          NaN                       NaN
# 176         Never tried it, but I'm open-minded.                       NaN
# 178                          Bring out the toys!  I'm indifferent to this.
# 213                                          NaN                       NaN
# 279    Not sure/don't know what they really are.               It's sweet.
# 303                          Bring out the toys!  I'm indifferent to this.
# 307                          Bring out the toys!                       NaN
# 346         Never tried it, but I'm open-minded.               It's sweet.
# 365                                          NaN                       NaN
# 366         Never tried it, but I'm open-minded.            It's annoying.
# 438                          Bring out the toys!  I'm indifferent to this.
# 443         Never tried it, but I'm open-minded.               It's sweet.
# 446                          Bring out the toys!                       NaN
# 475                                          NaN  I'm indifferent to this.
# 527                          Bring out the toys!               It's sweet.
# 549                          Bring out the toys!               It's sweet.
# 553         Never tried it, but I'm open-minded.               It's sweet.
# 618                                          NaN  I'm indifferent to this.
# 620         Never tried it, but I'm open-minded.  I'm indifferent to this.
# ...                                          ...                       ...
# 68081                                        NaN                       NaN
# 68083                                        NaN                       NaN
# 68086                                        NaN                       NaN
# 68088                                        NaN                       NaN
# 68089                                        NaN                       NaN
# 68094                                        NaN                       NaN
# 68095                                        NaN            It's annoying.
# 68096                                        NaN                       NaN
# 68102                                        NaN                       NaN
# 68104                                        NaN                       NaN
# 68109                                        NaN                       NaN
# 68122                                        NaN  I'm indifferent to this.
# 68123                                        NaN                       NaN
# 68126                                        NaN                       NaN
# 68131                                        NaN                       NaN
# 68132                                        NaN                       NaN
# 68139                                        NaN                       NaN
# 68150                                        NaN               It's sweet.
# 68161                                        NaN                       NaN
# 68163                                        NaN                       NaN
# 68170                                        NaN  I'm indifferent to this.
# 68171                                        NaN                       NaN
# 68180                                        NaN                       NaN
# 68191                                        NaN                       NaN
# 68200                                        NaN  I'm indifferent to this.
# 68202                                        NaN                       NaN
# 68213                                        NaN                       NaN
# 68215                                        NaN                       NaN
# 68247                                        NaN               It's sweet.
# 68290                                        NaN                       NaN
#
#            q7060                            q82301  \
# 25           Yes                               NaN
# 33           Yes                       Activities.
# 35     Sometimes                               NaN
# 39           Yes  Personal history or experiences.
# 40     Sometimes                               NaN
# 48           Yes                       Activities.
# 81           Yes                       Activities.
# 95           NaN                               NaN
# 120          Yes  Personal history or experiences.
# 164          NaN                               NaN
# 169          NaN                               NaN
# 171          NaN                               NaN
# 176           No                       Activities.
# 178          Yes       Politics or current events.
# 213          Yes                               NaN
# 279          NaN                               NaN
# 303    Sometimes  Personal history or experiences.
# 307          Yes                               NaN
# 346          Yes  Personal history or experiences.
# 365    Sometimes                       Activities.
# 366          Yes  Personal history or experiences.
# 438          Yes  Personal history or experiences.
# 443    Sometimes  Personal history or experiences.
# 446    Sometimes  Personal history or experiences.
# 475          NaN                       Activities.
# 527          Yes  Personal history or experiences.
# 549          Yes       Politics or current events.
# 553          Yes                               NaN
# 618          Yes  Personal history or experiences.
# 620          Yes                               NaN
# ...          ...                               ...
# 68081        NaN                               NaN
# 68083        NaN  Personal history or experiences.
# 68086        NaN                               NaN
# 68088        NaN                               NaN
# 68089  Sometimes                               NaN
# 68094        NaN                               NaN
# 68095        NaN                               NaN
# 68096        Yes                       Activities.
# 68102        Yes                       Activities.
# 68104  Sometimes                               NaN
# 68109        NaN                               NaN
# 68122        Yes  Personal history or experiences.
# 68123        NaN                               NaN
# 68126        NaN                               NaN
# 68131         No  Personal history or experiences.
# 68132        NaN                               NaN
# 68139  Sometimes                               NaN
# 68150        NaN                               NaN
# 68161        NaN                               NaN
# 68163  Sometimes                               NaN
# 68170         No                               NaN
# 68171  Sometimes                               NaN
# 68180        Yes  Personal history or experiences.
# 68191        NaN                               NaN
# 68200        NaN                               NaN
# 68202        NaN  Personal history or experiences.
# 68213        NaN                               NaN
# 68215        NaN                               NaN
# 68247        NaN  Personal history or experiences.
# 68290        NaN                               NaN
#
#                                    q85315                          q85835  \
# 25                                   Yes.              Starving children.
# 33                                   Yes.  Neither, they are equally bad.
# 35                                   Yes.  Neither, they are equally bad.
# 39                                   Yes.  Neither, they are equally bad.
# 40                                   Yes.              Starving children.
# 48                                   Yes.                 Abused animals.
# 81                                    NaN                             NaN
# 95                                   Yes.              Starving children.
# 120                                   NaN              Starving children.
# 164                                   NaN                             NaN
# 169                                   NaN                             NaN
# 171                                   NaN  Neither, they are equally bad.
# 176                                  Yes.  Neither, they are equally bad.
# 178                                   No.  Neither, they are equally bad.
# 213                                  Yes.              Starving children.
# 279                                   NaN              Starving children.
# 303                                  Yes.  Neither, they are equally bad.
# 307                                   NaN  Neither, they are equally bad.
# 346                                  Yes.  Neither, they are equally bad.
# 365                                  Yes.              Starving children.
# 366                                  Yes.              Starving children.
# 438                                  Yes.              Starving children.
# 443                                  Yes.              Starving children.
# 446                                  Yes.                             NaN
# 475                                   NaN                             NaN
# 527                                  Yes.              Starving children.
# 549                                   No.  Neither, they are equally bad.
# 553    I haven't had a past relationship.  Neither, they are equally bad.
# 618    I haven't had a past relationship.  Neither, they are equally bad.
# 620                                  Yes.              Starving children.
# ...                                   ...                             ...
# 68081                                 NaN                             NaN
# 68083                                 NaN                             NaN
# 68086                                Yes.                             NaN
# 68088                                 NaN                             NaN
# 68089                                Yes.  Neither, they are equally bad.
# 68094                                 NaN                             NaN
# 68095                                 NaN                             NaN
# 68096                                Yes.              Starving children.
# 68102                                 NaN                             NaN
# 68104                                 NaN  Neither, they are equally bad.
# 68109                                Yes.  Neither, they are equally bad.
# 68122                                 NaN              Starving children.
# 68123                                Yes.                             NaN
# 68126                                 No.  Neither, they are equally bad.
# 68131                                Yes.  Neither, they are equally bad.
# 68132                                Yes.                             NaN
# 68139                                 NaN  Neither, they are equally bad.
# 68150                                 NaN              Starving children.
# 68161                                 NaN  Neither, they are equally bad.
# 68163                                 NaN  Neither, they are equally bad.
# 68170                                Yes.  Neither, they are equally bad.
# 68171                                 NaN  Neither, they are equally bad.
# 68180                                 NaN                             NaN
# 68191                                 NaN                             NaN
# 68200                                 NaN  Neither, they are equally bad.
# 68202                                Yes.                 Abused animals.
# 68213                                 NaN                             NaN
# 68215                                 NaN              Starving children.
# 68247                                Yes.                             NaN
# 68290                                 NaN                             NaN
#
#                          q88             q9628 q26525 target
# 25               I'm average               Yes    Yes    Yes
# 33               I'm average                No    Yes    Yes
# 35               I'm average               Yes    NaN     No
# 39            I'm very messy               Yes    Yes     No
# 40      I'm mostly organized               NaN    Yes     No
# 48               I'm average               Yes    NaN     No
# 81      I'm mostly organized               NaN    Yes     No
# 95      I'm mostly organized               NaN    NaN     No
# 120                      NaN               Yes    Yes    Yes
# 164     I'm mostly organized               Yes    NaN     No
# 169              I'm average               Yes    NaN    Yes
# 171                      NaN               NaN    NaN     No
# 176              I'm average                No     No    Yes
# 178     I'm mostly organized               NaN    NaN     No
# 213                      NaN               Yes    NaN    Yes
# 279              I'm average                No    Yes     No
# 303     I'm mostly organized               Yes    Yes     No
# 307                      NaN               Yes    Yes    Yes
# 346     I'm mostly organized               Yes    Yes     No
# 365              I'm average               Yes    Yes    Yes
# 366              I'm average               Yes    NaN     No
# 438              I'm average               Yes    NaN    Yes
# 443              I'm average               Yes    Yes    Yes
# 446    I'm compulsively neat  Let's break skin    NaN     No
# 475     I'm mostly organized               NaN    Yes    Yes
# 527              I'm average               Yes    Yes     No
# 549           I'm very messy               Yes    Yes    Yes
# 553    I'm compulsively neat               Yes    Yes     No
# 618              I'm average               NaN    NaN     No
# 620              I'm average               Yes    Yes    Yes
# ...                      ...               ...    ...    ...
# 68081                    NaN               NaN    Yes    Yes
# 68083                    NaN               Yes    NaN     No
# 68086            I'm average               NaN    Yes     No
# 68088                    NaN                No    NaN    Yes
# 68089            I'm average               NaN    Yes     No
# 68094                    NaN               NaN    NaN     No
# 68095                    NaN                No    NaN     No
# 68096            I'm average               NaN    NaN     No
# 68102  I'm compulsively neat               NaN    NaN     No
# 68104                    NaN               NaN    NaN     No
# 68109                    NaN               NaN    NaN    Yes
# 68122   I'm mostly organized               NaN    NaN    Yes
# 68123            I'm average               NaN    NaN    Yes
# 68126                    NaN               NaN    NaN    Yes
# 68131            I'm average               NaN    NaN     No
# 68132                    NaN               NaN    NaN    Yes
# 68139                    NaN               NaN    Yes     No
# 68150            I'm average               NaN    NaN     No
# 68161   I'm mostly organized               NaN    NaN    Yes
# 68163                    NaN               NaN    NaN     No
# 68170         I'm very messy               Yes    NaN    Yes
# 68171            I'm average               NaN    Yes     No
# 68180                    NaN               NaN    Yes    Yes
# 68191                    NaN               NaN    NaN    Yes
# 68200   I'm mostly organized               NaN    Yes     No
# 68202                    NaN               NaN    NaN    Yes
# 68213                    NaN               NaN    NaN     No
# 68215            I'm average               NaN    NaN     No
# 68247                    NaN               NaN    NaN     No
# 68290                    NaN               NaN    NaN     No
#
# [28763 rows x 500 columns]

# %% [markdown]
# # Prep data for SQL

# %% [markdown]
# ## Helper functions

# %%
def get_SQL_type(string):
    """Takes a string representation of a python dtype and returns a string with a corresponding SQL data type.
    
    NOTE: This only knows how to handle 'float64' and 'object'.
    ALSO NOTE: It interprets 'float64' as int!
    
    This is very data and project specific right now!!"""

    if d_type == 'object':
        sql_type = 'VARCHAR(125)'

    elif d_type == 'float64':
        sql_type = 'INT'

    else:
        print('UNANTICIPATED DATA TYPE - only handles float64 and object')
    
    return sql_type



def print_SQL_schema(data, tablename = 'df_table'):
    """Takes a dataframe and prints out a SQL table creation statement
    
    Inputs:
    'data' = pandas dataframe
    'tablename' = string representing the desired name for the SQL table
    
    NOTE: SEE get_SQL_type() DOCSTRINGS FOR LIMITATIONS!"""
    
    #for use in the loop below
    first_col = True
    last_col_name = data.columns[-1]

    print('CREATE TABLE %s (' % (tablename))

    for col_name, d_type in data.dtypes.items():

        #checking for spaces within column names
        assert (str(col_name).find(' ') == -1), 'THERE IS A SPACE IN COLUMN NAME: %s'%(str(key))

        sql_type = get_SQL_type(d_type)

        if first_col:
            print('\t%s %s PRIMARY KEY,'%(col_name, sql_type))
            first_col = False

        elif col_name != last_col_name:
            print('\t%s %s,'%(col_name, sql_type))

        else:   #does not print comma if it's the last declared column
            print('\t%s %s'%(col_name, sql_type))

    print(');')

# %% [markdown]
# ## Generate table creation text

# %%
print_SQL_schema(df_1600, tablename = 'okcupid')
# Out:
# CREATE TABLE okcupid (
# 	username VARCHAR(125) PRIMARY KEY,
# 	q11 VARCHAR(125),
# 	q13 VARCHAR(125),
# 	q14 VARCHAR(125),
# 	q17 VARCHAR(125),
# 	q28 VARCHAR(125),
# 	q29 VARCHAR(125),
# 	q30 VARCHAR(125),
# 	q32 VARCHAR(125),
# 	q35 VARCHAR(125),
# 	q39 VARCHAR(125),
# 	q41 VARCHAR(125),
# 	q46 VARCHAR(125),
# 	q48 VARCHAR(125),
# 	q49 VARCHAR(125),
# 	q55 VARCHAR(125),
# 	q56 VARCHAR(125),
# 	q57 VARCHAR(125),
# 	q65 VARCHAR(125),
# 	q70 VARCHAR(125),
# 	q71 VARCHAR(125),
# 	q73 VARCHAR(125),
# 	q74 VARCHAR(125),
# 	q76 VARCHAR(125),
# 	q77 VARCHAR(125),
# 	q78 VARCHAR(125),
# 	q79 VARCHAR(125),
# 	q80 VARCHAR(125),
# 	q81 VARCHAR(125),
# 	q86 VARCHAR(125),
# 	q87 VARCHAR(125),
# 	q105 VARCHAR(125),
# 	q106 VARCHAR(125),
# 	q114 VARCHAR(125),
# 	q122 VARCHAR(125),
# 	q123 VARCHAR(125),
# 	q124 VARCHAR(125),
# 	q126 VARCHAR(125),
# 	q128 VARCHAR(125),
# 	q134 VARCHAR(125),
# 	q136 VARCHAR(125),
# 	q146 VARCHAR(125),
# 	q154 VARCHAR(125),
# 	q175 VARCHAR(125),
# 	q178 VARCHAR(125),
# 	q209 VARCHAR(125),
# 	q210 VARCHAR(125),
# 	q213 VARCHAR(125),
# 	q218 VARCHAR(125),
# 	q219 VARCHAR(125),
# 	q226 VARCHAR(125),
# 	q234 VARCHAR(125),
# 	q255 VARCHAR(125),
# 	q265 VARCHAR(125),
# 	q275 VARCHAR(125),
# 	q301 VARCHAR(125),
# 	q307 VARCHAR(125),
# 	q308 VARCHAR(125),
# 	q309 VARCHAR(125),
# 	q318 VARCHAR(125),
# 	q323 VARCHAR(125),
# 	q324 VARCHAR(125),
# 	q325 VARCHAR(125),
# 	q335 VARCHAR(125),
# 	q338 VARCHAR(125),
# 	q341 VARCHAR(125),
# 	q354 VARCHAR(125),
# 	q382 VARCHAR(125),
# 	q388 VARCHAR(125),
# 	q393 VARCHAR(125),
# 	q395 VARCHAR(125),
# 	q403 VARCHAR(125),
# 	q411 VARCHAR(125),
# 	q442 VARCHAR(125),
# 	q463 VARCHAR(125),
# 	q477 VARCHAR(125),
# 	q491 VARCHAR(125),
# 	q499 VARCHAR(125),
# 	q501 VARCHAR(125),
# 	q527 VARCHAR(125),
# 	q531 VARCHAR(125),
# 	q538 VARCHAR(125),
# 	q542 VARCHAR(125),
# 	q553 VARCHAR(125),
# 	q594 VARCHAR(125),
# 	q612 VARCHAR(125),
# 	q614 VARCHAR(125),
# 	q637 VARCHAR(125),
# 	q763 VARCHAR(125),
# 	q784 VARCHAR(125),
# 	q838 VARCHAR(125),
# 	q887 VARCHAR(125),
# 	q963 VARCHAR(125),
# 	q979 VARCHAR(125),
# 	q986 VARCHAR(125),
# 	q997 VARCHAR(125),
# 	q1028 VARCHAR(125),
# 	q1049 VARCHAR(125),
# 	q1052 VARCHAR(125),
# 	q1099 VARCHAR(125),
# 	q1112 VARCHAR(125),
# 	q1119 VARCHAR(125),
# 	q1122 VARCHAR(125),
# 	q1128 VARCHAR(125),
# 	q1132 VARCHAR(125),
# 	q1133 VARCHAR(125),
# 	q1158 VARCHAR(125),
# 	q1172 VARCHAR(125),
# 	q1173 VARCHAR(125),
# 	q1185 VARCHAR(125),
# 	q1201 VARCHAR(125),
# 	q1375 VARCHAR(125),
# 	q1401 VARCHAR(125),
# 	q1440 VARCHAR(125),
# 	q1446 VARCHAR(125),
# 	q1454 VARCHAR(125),
# 	q1597 VARCHAR(125),
# 	q1707 VARCHAR(125),
# 	q1712 VARCHAR(125),
# 	q1730 VARCHAR(125),
# 	q1815 VARCHAR(125),
# 	q2457 VARCHAR(125),
# 	q4018 VARCHAR(125),
# 	q5417 VARCHAR(125),
# 	q5764 VARCHAR(125),
# 	q6111 VARCHAR(125),
# 	q6258 VARCHAR(125),
# 	q6347 VARCHAR(125),
# 	q6350 VARCHAR(125),
# 	q6499 VARCHAR(125),
# 	q6537 VARCHAR(125),
# 	q6722 VARCHAR(125),
# 	q6867 VARCHAR(125),
# 	q7077 VARCHAR(125),
# 	q8054 VARCHAR(125),
# 	q8155 VARCHAR(125),
# 	q8672 VARCHAR(125),
# 	q8865 VARCHAR(125),
# 	q9379 VARCHAR(125),
# 	q9418 VARCHAR(125),
# 	q9447 VARCHAR(125),
# 	q9522 VARCHAR(125),
# 	q9668 VARCHAR(125),
# 	q9688 VARCHAR(125),
# 	q12503 VARCHAR(125),
# 	q12605 VARCHAR(125),
# 	q12964 VARCHAR(125),
# 	q12970 VARCHAR(125),
# 	q13006 VARCHAR(125),
# 	q13032 VARCHAR(125),
# 	q13054 VARCHAR(125),
# 	q13086 VARCHAR(125),
# 	q13669 VARCHAR(125),
# 	q14835 VARCHAR(125),
# 	q14913 VARCHAR(125),
# 	q15030 VARCHAR(125),
# 	q15037 VARCHAR(125),
# 	q15280 VARCHAR(125),
# 	q15372 VARCHAR(125),
# 	q15414 VARCHAR(125),
# 	q15698 VARCHAR(125),
# 	q15704 VARCHAR(125),
# 	q15742 VARCHAR(125),
# 	q15743 VARCHAR(125),
# 	q15752 VARCHAR(125),
# 	q15839 VARCHAR(125),
# 	q15889 VARCHAR(125),
# 	q16053 VARCHAR(125),
# 	q16317 VARCHAR(125),
# 	q16713 VARCHAR(125),
# 	q16862 VARCHAR(125),
# 	q17017 VARCHAR(125),
# 	q17168 VARCHAR(125),
# 	q17457 VARCHAR(125),
# 	q18125 VARCHAR(125),
# 	q18212 VARCHAR(125),
# 	q18504 VARCHAR(125),
# 	q18609 VARCHAR(125),
# 	q18692 VARCHAR(125),
# 	q18834 VARCHAR(125),
# 	q18843 VARCHAR(125),
# 	q18875 VARCHAR(125),
# 	q19011 VARCHAR(125),
# 	q19075 VARCHAR(125),
# 	q19265 VARCHAR(125),
# 	q19378 VARCHAR(125),
# 	q19392 VARCHAR(125),
# 	q19681 VARCHAR(125),
# 	q19854 VARCHAR(125),
# 	q19874 VARCHAR(125),
# 	q19898 VARCHAR(125),
# 	q19931 VARCHAR(125),
# 	q20135 VARCHAR(125),
# 	q20212 VARCHAR(125),
# 	q20240 VARCHAR(125),
# 	q20298 VARCHAR(125),
# 	q20418 VARCHAR(125),
# 	q20519 VARCHAR(125),
# 	q20530 VARCHAR(125),
# 	q20818 VARCHAR(125),
# 	q20889 VARCHAR(125),
# 	q20930 VARCHAR(125),
# 	q20976 VARCHAR(125),
# 	q20981 VARCHAR(125),
# 	q21175 VARCHAR(125),
# 	q21411 VARCHAR(125),
# 	q21527 VARCHAR(125),
# 	q21754 VARCHAR(125),
# 	q21793 VARCHAR(125),
# 	q21986 VARCHAR(125),
# 	q22021 VARCHAR(125),
# 	q22122 VARCHAR(125),
# 	q23132 VARCHAR(125),
# 	q23147 VARCHAR(125),
# 	q23293 VARCHAR(125),
# 	q23543 VARCHAR(125),
# 	q23696 VARCHAR(125),
# 	q23834 VARCHAR(125),
# 	q23993 VARCHAR(125),
# 	q24125 VARCHAR(125),
# 	q24282 VARCHAR(125),
# 	q24333 VARCHAR(125),
# 	q24345 VARCHAR(125),
# 	q24375 VARCHAR(125),
# 	q24684 VARCHAR(125),
# 	q25114 VARCHAR(125),
# 	q25228 VARCHAR(125),
# 	q25294 VARCHAR(125),
# 	q25561 VARCHAR(125),
# 	q26052 VARCHAR(125),
# 	q26299 VARCHAR(125),
# 	q26405 VARCHAR(125),
# 	q26529 VARCHAR(125),
# 	q26557 VARCHAR(125),
# 	q26573 VARCHAR(125),
# 	q26582 VARCHAR(125),
# 	q26720 VARCHAR(125),
# 	q27243 VARCHAR(125),
# 	q27477 VARCHAR(125),
# 	q27794 VARCHAR(125),
# 	q27921 VARCHAR(125),
# 	q28545 VARCHAR(125),
# 	q29032 VARCHAR(125),
# 	q29384 VARCHAR(125),
# 	q29389 VARCHAR(125),
# 	q29829 VARCHAR(125),
# 	q30115 VARCHAR(125),
# 	q30169 VARCHAR(125),
# 	q30271 VARCHAR(125),
# 	q30384 VARCHAR(125),
# 	q30416 VARCHAR(125),
# 	q30830 VARCHAR(125),
# 	q31055 VARCHAR(125),
# 	q31374 VARCHAR(125),
# 	q31488 VARCHAR(125),
# 	q31581 VARCHAR(125),
# 	q31840 VARCHAR(125),
# 	q31877 VARCHAR(125),
# 	q31920 VARCHAR(125),
# 	q32657 VARCHAR(125),
# 	q32855 VARCHAR(125),
# 	q32973 VARCHAR(125),
# 	q33170 VARCHAR(125),
# 	q33870 VARCHAR(125),
# 	q34113 VARCHAR(125),
# 	q34255 VARCHAR(125),
# 	q34333 VARCHAR(125),
# 	q35203 VARCHAR(125),
# 	q35475 VARCHAR(125),
# 	q35520 VARCHAR(125),
# 	q35660 VARCHAR(125),
# 	q35778 VARCHAR(125),
# 	q35862 VARCHAR(125),
# 	q35955 VARCHAR(125),
# 	q36045 VARCHAR(125),
# 	q37693 VARCHAR(125),
# 	q37708 VARCHAR(125),
# 	q38196 VARCHAR(125),
# 	q38223 VARCHAR(125),
# 	q38320 VARCHAR(125),
# 	q38423 VARCHAR(125),
# 	q38767 VARCHAR(125),
# 	q38838 VARCHAR(125),
# 	q40194 VARCHAR(125),
# 	q40288 VARCHAR(125),
# 	q40570 VARCHAR(125),
# 	q40944 VARCHAR(125),
# 	q41393 VARCHAR(125),
# 	q41850 VARCHAR(125),
# 	q41953 VARCHAR(125),
# 	q43261 VARCHAR(125),
# 	q43304 VARCHAR(125),
# 	q44384 VARCHAR(125),
# 	q44595 VARCHAR(125),
# 	q44639 VARCHAR(125),
# 	q45006 VARCHAR(125),
# 	q45428 VARCHAR(125),
# 	q45598 VARCHAR(125),
# 	q46176 VARCHAR(125),
# 	q46403 VARCHAR(125),
# 	q46563 VARCHAR(125),
# 	q46856 VARCHAR(125),
# 	q46927 VARCHAR(125),
# 	q47764 VARCHAR(125),
# 	q48325 VARCHAR(125),
# 	q48328 VARCHAR(125),
# 	q48347 VARCHAR(125),
# 	q48372 VARCHAR(125),
# 	q48753 VARCHAR(125),
# 	q48953 VARCHAR(125),
# 	q48981 VARCHAR(125),
# 	q49053 VARCHAR(125),
# 	q49107 VARCHAR(125),
# 	q50379 VARCHAR(125),
# 	q50564 VARCHAR(125),
# 	q50755 VARCHAR(125),
# 	q52682 VARCHAR(125),
# 	q52728 VARCHAR(125),
# 	q53540 VARCHAR(125),
# 	q53611 VARCHAR(125),
# 	q53965 VARCHAR(125),
# 	q54052 VARCHAR(125),
# 	q54127 VARCHAR(125),
# 	q54695 VARCHAR(125),
# 	q55264 VARCHAR(125),
# 	q55744 VARCHAR(125),
# 	q56606 VARCHAR(125),
# 	q57717 VARCHAR(125),
# 	q58812 VARCHAR(125),
# 	q59457 VARCHAR(125),
# 	q60100 VARCHAR(125),
# 	q60308 VARCHAR(125),
# 	q60756 VARCHAR(125),
# 	q60843 VARCHAR(125),
# 	q60852 VARCHAR(125),
# 	q60901 VARCHAR(125),
# 	q61786 VARCHAR(125),
# 	q62140 VARCHAR(125),
# 	q62254 VARCHAR(125),
# 	q63010 VARCHAR(125),
# 	q63114 VARCHAR(125),
# 	q64664 VARCHAR(125),
# 	q66506 VARCHAR(125),
# 	q66548 VARCHAR(125),
# 	q66827 VARCHAR(125),
# 	q67641 VARCHAR(125),
# 	q67821 VARCHAR(125),
# 	q68401 VARCHAR(125),
# 	q69186 VARCHAR(125),
# 	q69912 VARCHAR(125),
# 	q71315 VARCHAR(125),
# 	q72086 VARCHAR(125),
# 	q75677 VARCHAR(125),
# 	q80041 VARCHAR(125),
# 	q81307 VARCHAR(125),
# 	q82263 VARCHAR(125),
# 	q82528 VARCHAR(125),
# 	q82566 VARCHAR(125),
# 	q82681 VARCHAR(125),
# 	q83184 VARCHAR(125),
# 	q83480 VARCHAR(125),
# 	q83646 VARCHAR(125),
# 	q85419 VARCHAR(125),
# 	q86184 VARCHAR(125),
# 	q86366 VARCHAR(125),
# 	q86417 VARCHAR(125),
# 	q86544 VARCHAR(125),
# 	q86909 VARCHAR(125),
# 	q156913 VARCHAR(125),
# 	q156914 VARCHAR(125),
# 	q156915 VARCHAR(125),
# 	q156918 VARCHAR(125),
# 	q170849 VARCHAR(125),
# 	q179268 VARCHAR(125),
# 	q212813 VARCHAR(125),
# 	q212814 VARCHAR(125),
# 	q221105 VARCHAR(125),
# 	q221106 VARCHAR(125),
# 	q313640 VARCHAR(125),
# 	q358014 VARCHAR(125),
# 	q358077 VARCHAR(125),
# 	q358084 VARCHAR(125),
# 	q416235 VARCHAR(125),
# 	q416236 VARCHAR(125),
# 	q445141 VARCHAR(125),
# 	d_education_phase VARCHAR(125),
# 	d_gender VARCHAR(125),
# 	d_religion_type VARCHAR(125),
# 	d_drugs VARCHAR(125),
# 	lf_want VARCHAR(125),
# 	d_smokes VARCHAR(125),
# 	d_astrology_sign VARCHAR(125),
# 	d_country VARCHAR(125),
# 	d_drinks VARCHAR(125),
# 	d_age VARCHAR(125),
# 	d_ethnicity VARCHAR(125),
# 	d_bodytype VARCHAR(125),
# 	lf_max_age VARCHAR(125),
# 	lf_for VARCHAR(125),
# 	d_job VARCHAR(125),
# 	d_orientation VARCHAR(125),
# 	d_username VARCHAR(125),
# 	d_languages VARCHAR(125),
# 	d_relationship VARCHAR(125),
# 	lf_location VARCHAR(125),
# 	lf_min_age VARCHAR(125),
# 	d_city VARCHAR(125),
# 	d_education_type VARCHAR(125),
# 	lf_single VARCHAR(125),
# 	q1062 VARCHAR(125),
# 	q12584 VARCHAR(125),
# 	q1290 VARCHAR(125),
# 	q13136 VARCHAR(125),
# 	q149 VARCHAR(125),
# 	q1497 VARCHAR(125),
# 	q153 VARCHAR(125),
# 	q15478 VARCHAR(125),
# 	q155 VARCHAR(125),
# 	q15744 VARCHAR(125),
# 	q158 VARCHAR(125),
# 	q1588 VARCHAR(125),
# 	q165644 VARCHAR(125),
# 	q167 VARCHAR(125),
# 	q171 VARCHAR(125),
# 	q17342 VARCHAR(125),
# 	q1766 VARCHAR(125),
# 	q17778 VARCHAR(125),
# 	q18530 VARCHAR(125),
# 	q18547 VARCHAR(125),
# 	q18594 VARCHAR(125),
# 	q18682 VARCHAR(125),
# 	q18797 VARCHAR(125),
# 	q18979 VARCHAR(125),
# 	q19125 VARCHAR(125),
# 	q19365 VARCHAR(125),
# 	q19737 VARCHAR(125),
# 	q19815 VARCHAR(125),
# 	q20021 VARCHAR(125),
# 	q20062 VARCHAR(125),
# 	q20725 VARCHAR(125),
# 	q20778 VARCHAR(125),
# 	q21 VARCHAR(125),
# 	q21488 VARCHAR(125),
# 	q26684 VARCHAR(125),
# 	q26841 VARCHAR(125),
# 	q27 VARCHAR(125),
# 	q27164 VARCHAR(125),
# 	q27239 VARCHAR(125),
# 	q274 VARCHAR(125),
# 	q27672 VARCHAR(125),
# 	q28754 VARCHAR(125),
# 	q28831 VARCHAR(125),
# 	q28903 VARCHAR(125),
# 	q294 VARCHAR(125),
# 	q30207 VARCHAR(125),
# 	q30607 VARCHAR(125),
# 	q30723 VARCHAR(125),
# 	q30903 VARCHAR(125),
# 	q31983 VARCHAR(125),
# 	q33602 VARCHAR(125),
# 	q34094 VARCHAR(125),
# 	q34517 VARCHAR(125),
# 	q35276 VARCHAR(125),
# 	q35355 VARCHAR(125),
# 	q357 VARCHAR(125),
# 	q358080 VARCHAR(125),
# 	q359387 VARCHAR(125),
# 	q366 VARCHAR(125),
# 	q36790 VARCHAR(125),
# 	q38051 VARCHAR(125),
# 	q38173 VARCHAR(125),
# 	q38230 VARCHAR(125),
# 	q39185 VARCHAR(125),
# 	q39373 VARCHAR(125),
# 	q39576 VARCHAR(125),
# 	q40441 VARCHAR(125),
# 	q41099 VARCHAR(125),
# 	q42282 VARCHAR(125),
# 	q42918 VARCHAR(125),
# 	q44 VARCHAR(125),
# 	q44354 VARCHAR(125),
# 	q455 VARCHAR(125),
# 	q46780 VARCHAR(125),
# 	q48557 VARCHAR(125),
# 	q48947 VARCHAR(125),
# 	q496 VARCHAR(125),
# 	q53299 VARCHAR(125),
# 	q54016 VARCHAR(125),
# 	q61281 VARCHAR(125),
# 	q64 VARCHAR(125),
# 	q665 VARCHAR(125),
# 	q67418 VARCHAR(125),
# 	q7060 VARCHAR(125),
# 	q82301 VARCHAR(125),
# 	q85315 VARCHAR(125),
# 	q85835 VARCHAR(125),
# 	q88 VARCHAR(125),
# 	q9628 VARCHAR(125),
# 	q26525 VARCHAR(125),
# 	target VARCHAR(125)
# );

# %% [markdown]
# ## Export dataframe as .csv for SQL

# %%
df_1600.to_csv('df1600.csv', index=False)

# %% [markdown]
# # Put data into Postgres on EC2

# %% [markdown]
# Secure copy .csv file to EC2 instance (private key location omitted)

# %% [markdown]
# ![Copying to AWS Machine](img/secure_copy.png)

# %% [markdown]
# Create table in postgres using the table creation statement from section 2.2
# (*I omitted most of the lines from this image - there were 500 fields to declare*)

# %% [markdown]
# ![Building and copying table in SQL](img/aws_sql.png)
